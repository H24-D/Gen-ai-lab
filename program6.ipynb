# %% [markdown]
# <a href="https://colab.research.google.com/github/H24-D/Gen-ai-lab/blob/main/program6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
cache_dir="/content/drive/MyDrive/tranformer_cache"
os.makedirs(cache_dir,exist_ok=True)
os.environ["TRANSFORMERS_CACHE"]=cache_dir

# %%
import pandas as pd
from transformers import pipeline,AutoTokenizer,AutoModelForSequenceClassification
model_name="distilbert-base-uncased-finetuned-sst-2-english"
tokenizer=AutoTokenizer.from_pretrained(model_name,cache_dir=cache_dir)
model=AutoModelForSequenceClassification.from_pretrained(model_name,cache_dir=cache_dir)
sentiment_pipeline=pipeline("sentiment-analysis",model=model,tokenizer=tokenizer)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Device set to use cpu

# %%
sample_reviews=["I absolutely love this product"," it have an excellent features","product quality is good","satisified with product","Terrible experience","not worthy for money"]

# %%
sentiment_results=sentiment_pipeline(sample_reviews)

# %%
df_results=pd.DataFrame({
    "review":sample_reviews,
    "sentiment":[result['label'] for result in sentiment_results],
    "confidence score":[result['score'] for result in sentiment_results]
})
df_results
# Out:
#                            review sentiment  confidence score
# 0  I absolutely love this product  POSITIVE          0.999882
# 1   it have an excellent features  POSITIVE          0.999875
# 2         product quality is good  POSITIVE          0.999856
# 3         satisified with product  POSITIVE          0.981168
# 4             Terrible experience  NEGATIVE          0.999568
# 5            not worthy for money  NEGATIVE          0.999797

# %%
num_positive=sum(1 for res in sentiment_results if res["label"]=="POSITIVE")
num_negative=sum(1 for res in sentiment_results if res["label"]=="NEGATIVE")
total_reviews=len(sentiment_results)
positive_percentage=(num_positive/total_reviews)*100
negative_percentage=(num_negative/total_reviews)*100
if num_positive>num_negative:
  overall_sentiment="Positive"
  recommandation="we recomand the product based on positive reviews"
elif num_negative>num_positive:
  overall_sentiment="Negative"
  recommandation="we do not recomand the product based on positive reviews"
else:
  overall_sentiment="mixed"
  recommandation="the reviews are mixed consider other factors"
print("----Overall Analysis----")
print(f"Total reivews analyzed:{total_reviews}")
print(f"positive reviews:{num_positive}({positive_percentage:.1f}%)")
print(f"negative reviews:{num_negative}({negative_percentage:.1f}%)")
print(f"Overall sentiment:{overall_sentiment}")
print(f"Recommendation:{recommandation}")
# Out:
# ----Overall Analysis----
# Total reivews analyzed:6
# positive reviews:4(66.7%)
# negative reviews:2(33.3%)
# Overall sentiment:Positive
# Recommendation:we recomand the product based on positive reviews
